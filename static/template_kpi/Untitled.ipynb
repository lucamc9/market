# %%
import pandas as pd

# %%
excel = pd.ExcelFile('monthly-may.xlsx')

# %%
monthly_excel = excel.parse(excel.sheet_names[0])

# %%
monthly_excel
# Out:
#                                                                                                             CURRENT MONTH  \
# Income Statement Information NaN                                                                                      NaN
# NaN                          NaN                                                                                      NaN
#                              $  Sales by top customers                                                                NaN
#                              NaN                                                                               Customer A
#                              NaN                                                                               Customer B
#                              NaN                                                                               Customer C
#                              NaN                                                                               Customer D
# ...

# %%
monthly_excel[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/ml/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-cb1186aac02f> in <module>()
# ----> 1 monthly_excel[0]
#
# ...
